# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wsd.parsers import XLWSDParser, JMDictParser

jmdict = JMDictParser('data/JMdict_en.gz')
X, y = XLWSDParser.parse('ja')

# %%
k = 0
X[k], y[k]
# Out:
# (['ここ', 'に', 'ラマイム', 'の', '子', 'サレトマ', 'という', '者', 'が', 'いる', '.'],
#  [('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('O', 'O', 'O'),
#   ('いる', 'VERB', 'bn:00083184v'),
#   ('O', 'O', 'O')])

# %%
X
# Out:
# [['ここ',
#   'に',
#   'ラマイム',
#   'の',
#   '子',
#   'サレトマ',
#   'という',
#   '者',
#   'が',
#   'いる',
#   '.',
#   'むしろ',
#   ',',
#   'あなた',
#   'が',
#   'たの',
#   '宿',
#   'を',
#   'し',
#   'て',
#   'いる',
#   '時',
#   'に',
#   'は',
#   ',',
#   '新しい',
#   '時代',
#   'を',
#   '▁b',
#   'rought',
#   'し',
#   'て',
#   ',',
#   '新しい',
#   '時代',
#   'に',
#   'は',
#   ',',
#   '新た',
#   'に',
#   'し',
#   'て',
#   'くれ',
#   'た',
#   '.',
#   'あなた',
#   'は',
#   ',',
#   'クロトび',
#   'と',
#   'の',
#   '近く',
#   'において',
#   ',',
#   'クミロ',
#   'から',
#   '出',
#   'た',
#   'の',
#   'は',
#   'どこ',
#   'に',
#   'いる',
#   'の',
#   'か',
#   ',',
#   '力',
#   'の',
#   'ある',
#   '所',
#   'において',
#   ',',
#   'その',
#   '二',
#   '週',
#   'の',
#   '間',
#   'に',
#   '出',
#   'た',
#   'こと',
#   'が',
#   'ある',
#   'か',
#   '.',
#   'あなた',
#   'が',
#   'た',
#   'は',
#   ',',
#   '労働',
#   'を',
#   'し',
#   'て',
#   ',',
#   'あおぎ',
#   '分け',
#   'て',
#   'いる',
#   'の',
#   'を',
#   '見',
#   'て',
#   ',',
# ...
