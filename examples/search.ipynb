# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wsd.models import JMDict

# %%
searcher = JMDict()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 searcher = JMDict()
#
# File ~/workspace/linalgo/wsd/wsd/models/baseline.py:8, in JMDict.__init__(self)
#       7 def __init__(self):
# ----> 8     self.entries = JMDictParser().parse('data/JMdict_en.gz')
#
# File ~/workspace/linalgo/wsd/wsd/parsers/jmdict.py:121, in JMDictParser.parse(cls, file_path)
#     119 """Parse a JMdict file"""
#     120 entries = []
# --> 121 with gzip.open(file_path, "rb") as f:  # pylint: disable=invalid-name
#     122     tree = ET.parse(f)
#     123     root = tree.getroot()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/gzip.py:58, in open(filename, mode, compresslevel, encoding, errors, newline)
#      56 gz_mode = mode.replace("t", "")
#      57 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58     binary_file = GzipFile(filename, gz_mode, compresslevel)
# ...

# %%
searcher.search('犬')
# Out:
# [{'ent_seq': '1258330', 'r_ele': [{'reb': 'いぬ', 're_nokanji': False, 're_restr': [], 're_inf': [], 're_pri': ['ichi1', 'news1', 'nf03']}, {'reb': 'イヌ', 're_nokanji': False, 're_restr': [], 're_inf': [], 're_pri': []}], 'sense': [{'stagk': [], 'stagr': [], 'pos': ['noun (common) (futsuumeishi)'], 'xref': [], 'ant': [], 'field': [], 'misc': [], 'lsource': [], 'dial': [], 'gloss': [{'text': 'dog (Canis (lupus) familiaris)', 'lang': 'eng'}], 's_inf': None}, {'stagk': [], 'stagr': [], 'pos': ['noun (common) (futsuumeishi)'], 'xref': ['みっこくしゃ'], 'ant': [], 'field': [], 'misc': ['derogatory', 'word usually written using kana alone'], 'lsource': [], 'dial': [], 'gloss': [{'text': 'squealer', 'lang': 'eng'}, {'text': 'rat', 'lang': 'eng'}, {'text': 'snitch', 'lang': 'eng'}, {'text': 'informer', 'lang': 'eng'}, {'text': 'informant', 'lang': 'eng'}, {'text': 'spy', 'lang': 'eng'}], 's_inf': None}, {'stagk': [], 'stagr': [], 'pos': ['noun (common) (futsuumeishi)'], 'xref': [], 'ant': [], 'field'
# ...
